# %% [markdown]
# # Pyber Challenge

# %% [markdown]
# ### 4.3 Loading and Reading CSV files

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# File to Load (Remember to change these)
city_data_to_load = "Resources/city_data.csv"
ride_data_to_load = "Resources/ride_data.csv"

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %% [markdown]
# ### Merge the DataFrames

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, 
                         how="left", on=["city", "city"])

# Display the data table for preview
pyber_data_df.head()
# Out:
#                  city             date   fare       ride_id  driver_count  \
# 0  Lake Jonathanshire  1/14/2019 10:14  13.83  5.739410e+12             5
# 1  South Michelleport   3/4/2019 18:24  30.24  2.343910e+12            72
# 2  Port Samanthamouth   2/24/2019 4:29  33.44  2.005070e+12            57
# 3          Rodneyfort  2/10/2019 23:22  23.44  5.149250e+12            34
# 4          South Jack    3/6/2019 4:28  34.58  3.908450e+12            46
#
#     type
# 0  Urban
# 1  Urban
# 2  Urban
# 3  Urban
# 4  Urban

# %% [markdown]
# ## Deliverable 1: Get a Summary DataFrame

# %%
#  1. Get the total rides for each city type
ride_total_by_city = pyber_data_df.groupby(['type']).count()['ride_id']
ride_total_by_city
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: ride_id, dtype: int64

# %%
# 2. Get the total drivers for each city type
driver_total_by_city = city_data_df.groupby(['type']).sum()['driver_count']
driver_total_by_city
# Out:
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %%
#  3. Get the total amount of fares for each city type
fare_total_by_city = pyber_data_df.groupby(['type']).sum()['fare']
fare_total_by_city
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
#  4. Get the average fare per ride for each city type. 
average_fare_by_city = fare_total_by_city / ride_total_by_city
average_fare_by_city
# Out:
# type
# Rural       34.623440
# Suburban    30.970128
# Urban       24.525772
# dtype: float64

# %%
# 5. Get the average fare per driver for each city type. 
average_fare_by_driver = fare_total_by_city / driver_total_by_city
average_fare_by_driver
# Out:
# type
# Rural       55.486282
# Suburban    39.502714
# Urban       16.571468
# dtype: float64

# %%
#  6. Create a PyBer summary DataFrame. 
pyber_summary_df = pd.DataFrame({'Total Rides': ride_total_by_city, 
                                 'Total Drivers': driver_total_by_city, 
                                 'Total Fares': fare_total_by_city, 
                                 'Average Fare per Ride': average_fare_by_city,
                                 'Average Fare per Driver': average_fare_by_driver})
pyber_summary_df
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# type
# Rural             125             78      4327.93              34.623440
# Suburban          625            490     19356.33              30.970128
# Urban            1625           2405     39854.38              24.525772
#
#           Average Fare per Driver
# type
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
#  7. Cleaning up the DataFrame. Delete the index name
pyber_summary_df.index.name = None
pyber_summary_df
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# Rural             125             78      4327.93              34.623440
# Suburban          625            490     19356.33              30.970128
# Urban            1625           2405     39854.38              24.525772
#
#           Average Fare per Driver
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
#  8. Format the columns.
pyber_summary_df["Total Rides"] = pyber_summary_df["Total Rides"].map("{:,.0f}".format)  
pyber_summary_df["Total Drivers"] = pyber_summary_df["Total Drivers"].map("{:,.0f}".format)  
pyber_summary_df["Total Fares"] = pyber_summary_df["Total Fares"].map("${:,.2f}".format)  
pyber_summary_df["Average Fare per Ride"] = pyber_summary_df["Average Fare per Ride"].map("${:,.2f}".format)  
pyber_summary_df["Average Fare per Driver"] = pyber_summary_df["Average Fare per Driver"].map("${:,.2f}".format)  

pyber_summary_df
# Out:
#          Total Rides Total Drivers Total Fares Average Fare per Ride  \
# Rural            125            78   $4,327.93                $34.62
# Suburban         625           490  $19,356.33                $30.97
# Urban          1,625         2,405  $39,854.38                $24.53
#
#          Average Fare per Driver
# Rural                     $55.49
# Suburban                  $39.50
# Urban                     $16.57

# %% [markdown]
# # Deliverable 2.  Create a multiple line plot that shows the total weekly of the fares for each type of city.

# %%
# 1. Read the merged DataFrame
pyber_data_df
# Out:
#                     city             date   fare       ride_id  driver_count  \
# 0     Lake Jonathanshire  1/14/2019 10:14  13.83  5.739410e+12             5
# 1     South Michelleport   3/4/2019 18:24  30.24  2.343910e+12            72
# 2     Port Samanthamouth   2/24/2019 4:29  33.44  2.005070e+12            57
# 3             Rodneyfort  2/10/2019 23:22  23.44  5.149250e+12            34
# 4             South Jack    3/6/2019 4:28  34.58  3.908450e+12            46
# ...                  ...              ...    ...           ...           ...
# 2370         Michaelberg  4/29/2019 17:04  13.38  8.550370e+12             6
# 2371     Lake Latoyabury   1/30/2019 0:05  20.76  9.018730e+12             2
# 2372         North Jaime  2/10/2019 21:03  11.11  2.781340e+12             1
# 2373        West Heather   5/7/2019 19:22  44.94  4.256850e+12             4
# 2374          Newtonview  4/25/2019 10:20  55.84  9.990580e+12             1
#
#        type
# 0     Urban
# 1     Urban
# ...

# %%
# 2. Using groupby() to create a new DataFrame showing the sum of the fares 
#  for each date where the indices are the city type and date.
fares_by_type_date = pyber_data_df.groupby(['type','date']).sum()['fare']
fares_by_type_date
# Out:
# type   date
# Rural  1/1/2019 9:45      43.69
#        1/11/2019 4:39     16.42
#        1/14/2019 15:58    54.10
#        1/14/2019 7:09     18.05
#        1/15/2019 21:44    30.26
#                           ...
# Urban  5/8/2019 1:54      32.69
#        5/8/2019 2:31      41.33
#        5/8/2019 4:20      21.99
#        5/8/2019 4:39      18.45
#        5/8/2019 7:29      18.55
# Name: fare, Length: 2364, dtype: float64

# %%
# 3. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.
# df = df.reset_index()
fares_by_type_date =fares_by_type_date.reset_index()
fares_by_type_date
# Out:
#        type             date   fare
# 0     Rural    1/1/2019 9:45  43.69
# 1     Rural   1/11/2019 4:39  16.42
# 2     Rural  1/14/2019 15:58  54.10
# 3     Rural   1/14/2019 7:09  18.05
# 4     Rural  1/15/2019 21:44  30.26
# ...     ...              ...    ...
# 2359  Urban    5/8/2019 1:54  32.69
# 2360  Urban    5/8/2019 2:31  41.33
# 2361  Urban    5/8/2019 4:20  21.99
# 2362  Urban    5/8/2019 4:39  18.45
# 2363  Urban    5/8/2019 7:29  18.55
#
# [2364 rows x 3 columns]

# %%
# 4. Create a pivot table with the 'date' as the index, the columns ='type', and values='fare' 
# to get the total fares for each type of city by the date. 
fares_by_date = fares_by_type_date.pivot(index = 'date',
                                         columns = 'type',
                                         values = 'fare')
fares_by_date
# Out:
# type            Rural  Suburban  Urban
# date
# 1/1/2019 0:08     NaN       NaN  37.91
# 1/1/2019 0:46     NaN     47.74    NaN
# 1/1/2019 12:32    NaN     25.56    NaN
# 1/1/2019 14:40    NaN       NaN   5.42
# 1/1/2019 14:42    NaN       NaN  12.31
# ...               ...       ...    ...
# 5/8/2019 1:54     NaN       NaN  32.69
# 5/8/2019 2:31     NaN       NaN  41.33
# 5/8/2019 4:20     NaN       NaN  21.99
# 5/8/2019 4:39     NaN       NaN  18.45
# 5/8/2019 7:29     NaN       NaN  18.55
#
# [2361 rows x 3 columns]

# %%
# 5. Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-29'.
fares_by_date_updated = fares_by_date.loc['1/1/2019':'4/29/2019']
fares_by_date_updated
# Out:
# type            Rural  Suburban  Urban
# date
# 1/1/2019 0:08     NaN       NaN  37.91
# 1/1/2019 0:46     NaN     47.74    NaN
# 1/1/2019 12:32    NaN     25.56    NaN
# 1/1/2019 14:40    NaN       NaN   5.42
# 1/1/2019 14:42    NaN       NaN  12.31
# ...               ...       ...    ...
# 4/28/2019 4:34    NaN       NaN  40.46
# 4/28/2019 8:15    NaN       NaN  22.86
# 4/28/2019 9:03    NaN       NaN  15.00
# 4/28/2019 9:10    NaN       NaN   5.73
# 4/28/2019 9:25    NaN       NaN  37.35
#
# [2057 rows x 3 columns]

# %%
# 6. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.
# df.index = pd.to_datetime(df.index)
fares_by_date_updated.index = pd.to_datetime(fares_by_date_updated.index)

# %%
# 7. Check that the datatype for the index is datetime using df.info()
fares_by_date_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2057 entries, 2019-01-01 00:08:00 to 2019-04-28 09:25:00
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rural     105 non-null    float64
#  1   Suburban  538 non-null    float64
#  2   Urban     1416 non-null   float64
# dtypes: float64(3)
# memory usage: 64.3 KB

# %%
# 8. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.
fares_by_week = fares_by_date_updated.resample('W').sum()
fares_by_week
# Out:
# type         Rural  Suburban    Urban
# date
# 2019-01-06  187.92    721.60  1661.68
# 2019-01-13   67.65   1105.13  2050.43
# 2019-01-20  306.00   1218.20  1939.02
# 2019-01-27  179.69   1203.28  2129.51
# 2019-02-03  333.08   1042.79  2086.94
# 2019-02-10  115.80    974.34  2162.64
# 2019-02-17   95.82   1045.50  2235.07
# 2019-02-24  419.06   1412.74  2466.29
# 2019-03-03  175.14    858.46  2218.20
# 2019-03-10  303.94    925.27  2470.93
# 2019-03-17  163.39    906.20  2044.42
# 2019-03-24  189.76   1122.20  2368.37
# 2019-03-31  199.42   1045.06  1942.77
# 2019-04-07  177.65    354.49   613.93
# 2019-04-14  214.60    568.47  2024.25
# 2019-04-21  214.14   1149.27  2303.80
# 2019-04-28  191.85   1357.75  2238.29

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function. 

# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')
fig, ax  = plt.subplots(figsize = (20,6))


rural_fares = fares_by_week['Rural']
suburban_fares = fares_by_week['Suburban']
urban_fares = fares_by_week['Urban']

ax.plot(rural_fares.index, rural_fares,
        label = "Rural")
ax.plot(suburban_fares.index, suburban_fares,
        label = "Suburban")
ax.plot(urban_fares.index, urban_fares,
        label = "Urban")

fares_by_month = fares_by_date_updated.resample('M').sum().index

ax.set_xticks(fares_by_month)
ax.set_xlim(pd.Timestamp('2019-01-06'),pd.Timestamp('2019-04-28'))

# Set the chart label information.
lgnd = ax.legend(fontsize="12", scatterpoints=1, loc="center", title="type")
lgnd.get_title().set_fontsize(12)
ax.set_title("Total Fare by City Type")
ax.set_ylabel("Fare($USD)")
ax.grid(True)

# Save a chart as an image.
plt.savefig("analysis/PyBer_fare_summary.png")

# Show chart.
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
